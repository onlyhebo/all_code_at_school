# %%
from selenium import webdriver 
from pyquery import PyQuery as pq
import time
browser = webdriver.Firefox()
browser.get("https://www.zhihu.com/")
browser.maximize_window()
browser.find_element_by_css_selector('.SignContainer-switch span').click()
browser.find_element_by_name('username').send_keys('18215609986')
browser.find_element_by_name('password').send_keys('hb7615501@')
browser.find_element_by_css_selector('.Button.SignFlow-submitButton.Button--primary.Button--blue').click()

# %%
browser.find_element_by_css_selector('.Popover input').send_keys('武汉理工大学陶崇园')
browser.find_element_by_css_selector('.Button.SearchBar-searchIcon.Button--primary').click()
Card = browser.find_elements_by_css_selector('#SearchMain .Card')

# %%
li = Card[1].find_elements_by_css_selector('.List-item')
url = li[0].find_element_by_css_selector('h2 a').get_attribute('href')
js='window.open("' + url +'")'
browser.execute_script(js)
handles = browser.window_handles
#browser.switch_to_window(handles[2])
#browser.find_element_by_css_selector('.Card .QuestionMainAction').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-d3eb437fa676> in <module>()
#       6 #browser.switch_to_window(handles[2])
#       7 #browser.find_element_by_css_selector('.Card .QuestionMainAction').text
# ----> 8 print(browser.text)
#
# AttributeError: 'WebDriver' object has no attribute 'text'

# %%
windows = browser.window_handles
# 切换到当前最新打开的窗口
browser.switch_to.window(windows[-1])

# %%
print(browser.find_element_by_css_selector('.Card .QuestionMainAction').text)
# Out:
# 查看全部 779 个回答

# %%
browser.find_element_by_css_selector('.Card .QuestionMainAction').click()

# %%
browser.find_element_by_css_selector('.RichText.CopyrightRichText-richText').text
# Out:
# '手动置顶：\n共青团中央知乎官方账号的发声 如何评价武汉理工大学陶崇园事件中校方的反应及态度？\n上传陶崇园姐姐接受媒体采访的视频未通过知乎审核，国内其他网络资源目前也均无法播放：\n有条件的朋友请科学上网观看：\n武汉理工研究生坠楼会议录音曝光 家属逐一反驳\n（感谢 \n@猪鼻不错fhh\n 提供的不用搭梯的资源。已在评论区置顶，请移步评论区点击链接观看。）\n武汉理工坠楼案家属称死者被导师叫家里捶背按摩\n\n几点补充说明：\n评论区一些朋友的意思我明白，但请不要过度联想，将此事件与某历史事件过度联系。这种联系无助于事件向着健康的方向发展。而不相关的联系和言论越多，反而很可能是事件中心某些人/某些机构所乐见的；\n人微言轻的道理我也懂，我的一点点声音也许对事件的进展不会有丝毫影响，我不否认。可是难道应该万马齐喑，人人噤若寒蝉，等待社会的自我修复自然启动吗？如果这种机制像分子生物学中的各种调控、修饰一样精密，我自然没什么话说；\n对家父，没有鄙夷的意思。理解，但不认同。当然，会有一点失望。这种失望，有，但更多的不是针对他个人，说起来是一种非常复杂的情绪；\n我们选择发声，别人也自然可以选择沉默。我们可以影响他人的认识，但道德绑架就没有必要了。不过对于是非观明显错乱的观点，比如“陶/现在的年轻人就是心理脆弱/抗压能力差”、“帮老师干点儿活怎么了”这种，一定要坚决回怼。你说会有这样的人吗？\n\n\n\n要不是亲眼所见，我真的无论如何想象不到人性竟然还有这样的一面。无论博主是否真的是这样的三观，蹭热度吃人血馒头同样可恶。\n以下是原答案：\n\n不要说学校了。我爸，平时联系并不频繁，都特意打电话约谈我（发了几条特意没有屏蔽家人的朋友圈）。要我不要太过关注此次事件；要我不要总盯着社会阴暗面，要多看主流（主流难道不永远是祖国山河一片红，太平盛世朗朗乾坤吗？）；说不要全赖社会赖导师…… （我并没有在目前真相没有大白于天下的前提下就预设立场对任何人做有罪推断，但是觉得尽自己的一份力让事件保持热度有助于还原事件真相，让相关责任人及/或机构不逃脱正义的审判，给死者及其家属以告慰。）\n我爸，文化程度不说多高，好歹985大学毕业，是同龄人中少有的接受过高等教育的一分子。要真是文化程度有限，没有明确的是非观也就算了。作为一个父亲，他以这样的立场劝我我理解（嗯，理解但不认同。当
# ...

# %%
print(browser_1)
# Out:
# None

# %%
print(browser_1)
# Out:
# None

# %%
browser_1.find_element_by_css_selector('.QuestionMainAction').click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-88d0fb8a8d77> in <module>()
# ----> 1 browser_1.find_element_by_css_selector('.QuestionMainAction').click()
#
# AttributeError: 'NoneType' object has no attribute 'find_element_by_css_selector'

# %%
doc = pq(browser.page_source)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-f6c8a2753d8f> in <module>()
#       1 doc = pq(browser.page_source)
# ----> 2 doc('a').click()
#
# AttributeError: 'PyQuery' object has no attribute 'click'

# %%
print(doc)
# Out:
# <html data-theme="light" data-focus-method="keyboard" lang="zh"><head><meta charset="utf-8"/><title>(38 条消息)武汉理工大学陶崇园 - 搜索结果 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><link rel="shortcut icon" type="image/x-icon" href="https://static.zhihu.com/static/favicon.ico"/><link rel="dns-prefetch" href="//static.zhimg.com"/><link rel="dns-prefetch" href="//pic1.zhimg.com"/><link rel="dns-prefetch" href="//pic2.zhimg.com"/><link rel="dns-prefetch" href="//pic3.zhimg.com"/><link rel="dns-prefetch" href="//pic4.zhimg.com"/><link href="https://static.zhihu.com/heifetz/main.app.8805f88891008fe3153a.css" rel="stylesheet"/><script type="text/javascript" charset="utf-8" async="" src="https://static.zhihu.com/
# ...

# %%
browser.find_elements_by_css_selector('')

# %%
print(browser.page_source)
# Out:
# <html data-theme="light" lang="zh"><head><meta charset="utf-8"><title>(37 条消息)武汉理工大学陶崇园 - 搜索结果 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"><meta name="renderer" content="webkit"><meta name="force-rendering" content="webkit"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"><link rel="shortcut icon" type="image/x-icon" href="https://static.zhihu.com/static/favicon.ico"><link rel="dns-prefetch" href="//static.zhimg.com"><link rel="dns-prefetch" href="//pic1.zhimg.com"><link rel="dns-prefetch" href="//pic2.zhimg.com"><link rel="dns-prefetch" href="//pic3.zhimg.com"><link rel="dns-prefetch" href="//pic4.zhimg.com"><link href="https://static.zhihu.com/heifetz/main.app.8805f88891008fe3153a.css" rel="stylesheet"><script type="text/javascript" charset="utf-8" async="" src="https://static.zhihu.com/heifetz/main.modals.9832d01407f7fa4ae0fa.j
# ...

# %%
for  i in range(100):
    js="var q=document.documentElement.scrollTop=10000000"  
    browser.execute_script(js)

# %%
agree = browser.find_elements_by_css_selector('.Button.VoteButton.VoteButton--up')

# %%
for agr in agree:
    print(agr.text)
# Out:
# 6.2K
# 4.2K
# 422
# 56
# 561
# 52
# 3.7K
# 11K
# 852
# 84
# 300
# 97
# 1.4K
# 763
# 553
# 202
# 417
# 125
# 2.7K
# 1.4K
# 2.4K
# 406
# 312
# 2.2K
# 7.6K
# 4.4K
# 1.1K
# 3.1K
# 98
# 1.2K
# 3.9K
# 140
# 168
# 2.3K
# 6.5K
# 123
# 4.1K
# 21
# 13K
# 1.5K
# 2.4K
# 66
# 15K
# 385
# 144
# 8.8K
# 406
# 3.1K
# 3.8K
# 2K
# 39
# 785
# 5.4K
# 413
# 588
# 1.2K
# 1.4K
# 886
# 92
# 15K
# 2.7K
# 39
# 231
# 334
# 351
# 523
# 2.3K
# 230
# 487
# 9.2K
# 410
# 2.6K
# 7.2K
# 3.4K
# 420
