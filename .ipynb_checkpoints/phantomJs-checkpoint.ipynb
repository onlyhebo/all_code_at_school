# %%
from selenium import webdriver 
from pyquery import PyQuery as pq
import time
driver = webdriver.PhantomJS()
# Out:
# c:\python36\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
driver.get('https://www.zhihu.com/question/270773664')
driver.maximize_window()
driver.get("http\:example.com")

# %%
driver.find_elements_by_css_selector('div.List-item:nth-child(3)')
# Out:
# []

# %%
from selenium import webdriver # 引入配置对象DesiredCapabilities 
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities 
dcap = dict(DesiredCapabilities.PHANTOMJS) #从USER_AGENTS列表中随机选一个浏览器头，伪装浏览器 
dcap["phantomjs.page.settings.userAgent"] = ("Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2623.221 Safari/537.36 SE 2.X MetaSr 1.0") # 不载入图片，爬页面速度会快很多 
dcap["phantomjs.page.settings.loadImages"] = False # 设置代理 
service_args = ['--proxy=127.0.0.1:9999','--proxy-type=socks5'] #打开带配置信息的phantomJS浏览器 
driver = webdriver.PhantomJS(desired_capabilities=dcap,service_args=service_args) # 隐式等待5秒，可以自己调节 
driver.implicitly_wait(5) # 设置10秒页面超时返回，类似于requests.get()的timeout选项，driver.get()没有timeout选项 # 以前遇到过driver.get(url)一直不返回，但也不报错的问题，这时程序会卡住，设置超时选项能解决这个问题。 
driver.set_page_load_timeout(10) # 设置10秒脚本超时时间 
driver.set_script_timeout(10)
# Out:
# c:\python36\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
driver.get('http://s.weibo.com/weibo/%25E9%2599%25B6%25E5%25B4%2587%25E5%259B%25AD&Refer=focus_lx_STopic_box')

# %%
driver.find_elements_by_css_selector('.WB_cardwrap.S_bg2.clearfix')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="94b07700-3b2d-11e8-927b-33b31c8aa6bd", element=":wdc:1523192774948")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b07700-3b2d-11e8-927b-33b31c8aa6bd", element=":wdc:1523192774949")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b07700-3b2d-11e8-927b-33b31c8aa6bd", element=":wdc:1523192774950")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b07700-3b2d-11e8-927b-33b31c8aa6bd", element=":wdc:1523192774951")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b07700-3b2d-11e8-927b-33b31c8aa6bd", element=":wdc:1523192774952")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b07700-3b2d-11e8-927b-33b31c8aa6bd", element=":wdc:1523192774953")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b07700-3b2d-11e8-927b-33b31c8aa6bd", element=":wdc:1523192774954")>,
# ...

# %%
driver.page_source
# Out:
# '<html><head></head><body></body></html>'

# %%
for i in range(10):
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    time.sleep(1)

# %%
browser = webdriver.Firefox()
browser.get('https://www.zhihu.com/question/270773664')
for i in range(10):
    js="var q=document.documentElement.scrollTop=100000"  
    browser.execute_script(js) 
time.sleep(10)
browser.find_elements_by_css_selector('.List-item')
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="dfaecf13-5e55-4528-a11a-a750d8dbe126", element="8a30624e-286a-4f59-814a-99bd4074eef1")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="dfaecf13-5e55-4528-a11a-a750d8dbe126", element="3ebf6b9a-5fb8-4cb4-93a8-9f80549df0b8")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="dfaecf13-5e55-4528-a11a-a750d8dbe126", element="b340b114-8b38-4a07-be0a-640e98ec7b4f")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="dfaecf13-5e55-4528-a11a-a750d8dbe126", element="dd1fa54d-e566-4430-b29a-7d898e3f7f66")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="dfaecf13-5e55-4528-a11a-a750d8dbe126", element="2c1c8eb7-dc73-402c-878b-f3d687a3af38")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="dfaecf13-5e55-4528-a11a-a750d8dbe126", element="4cf85762-b36b-456b-84be-d9ee8df9472e")>,
# ...

# %%
import bs4
from bs4 import BeautifulSoup  
from selenium import webdriver
from selenium.common.exceptions import TimeoutException

#利用PhantomJS加载网页
browser = webdriver.PhantomJS()
browser.set_page_load_timeout(30) # 最大等待时间为30s
#当加载时间超过30秒后，自动停止加载该页面
try:
    browser.get('https://www.zhihu.com/question/270773664')
except TimeoutException:
    browser.execute_script('window.stop()')
source = browser.page_source #获取网页源代码
browser.quit()
#解析网页，获取下载图片的网址
soup = BeautifulSoup(source,'lxml')      
image = soup.find_all('.List-item')
print(image)
# Out:
# c:\python36\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# []

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
from selenium import webdriver 
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
import time

# %%
def wait(driver):  
    #elem = driver.find_element_by_tag_name('html')
    count = 0  
    while True:  
        count +=1  
        if count>20:  
            print('timeout')  
            return  
        time.sleep(5)  
        try:  
            driver.find_element_by_css_selector('div.List-item:nth-child(3)')  
        except StaleElementReferenceException:  
            return

# %%
drive = webdriver.PhantomJS()
drive.get('https://www.zhihu.com/question/270773664')
# Out:
# c:\python36\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
wait(drive)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-e903b6cc0bb5> in <module>()
# ----> 1 wait(drive)
#
# <ipython-input-15-3f276ebbddcd> in wait(driver)
#       8         time.sleep(5)
#       9         try:
# ---> 10             elem == driver.find_element_by_css_selector('div.List-item:nth-child(3)')
#      11         except StaleElementReferenceException:
#      12             return
#
# NameError: name 'elem' is not defined
